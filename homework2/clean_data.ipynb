# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os 
import glob
import re
import toolz.curried as tl
import datetime

# %%
DATA_FILES = glob.glob(os.path.join(os.getcwd(), "data", "original_data", "*.xls*"))

# %%
print(*map(os.path.basename, DATA_FILES))
# Out:
# Houston_Complete_Sorted.xlsm Limestone_Complete_Sorted.xlsm Madison_Irrigated_2.xls Madison_Rainfed_2.xls

# %% [markdown]
# Quickly looking through the data in excel we can see that madison is separated into two files for rainfed and irrigated where as houston and limestone have a column for a flag to tell if it is rainfed or irrigated. First step is to get all the files to have similar formats so I will aggregate the two madison files into one.

# %%
def find_file(regex, files):
    for file in files:
        if re.search(regex, file):
            return file
    raise ValueError("No File Found.")

# %%
madison_rf_df = pd.read_excel(find_file(r".*Madison_Rain.*", DATA_FILES))
limestone_df = pd.read_excel(find_file(r".*Limestone.*", DATA_FILES))
houston_df = pd.read_excel(find_file(r".*Houston.*", DATA_FILES))
madison_irr_df = pd.read_excel(find_file(r".*Madison_Irr.*", DATA_FILES))

# %%
rf_cols = sorted(madison_rf_df.columns)
irr_cols = sorted(madison_irr_df.columns)
for i in range(len(rf_cols)):
    if rf_cols[i] != irr_cols[i]:
        print(f"index {i}\n{rf_cols[i]} != {irr_cols[i]}")

# %%
madison_rf_df["rf_irr"] = 0
madison_irr_df["rf_irr"] = 1

# %%
madison_rf_df.head()
# Out:
#    Longitude   Latitude  MOD13Q1_006__250m_16_days_EVI_doy2011081_aid0001_tif  \
# 0 -86.779999  34.990601                                               3413
# 1 -86.777496  34.990601                                               3281
# 2 -86.764801  34.990601                                               4045
# 3 -86.757202  34.990601                                               4167
# 4 -86.754600  34.990601                                               4256
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012081_aid0001_tif  \
# 0                                               3747
# 1                                               3747
# 2                                               4696
# 3                                               5114
# 4                                               5114
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011097_aid0001_tif  \
# 0                                               4421
# 1                                               4421
# 2                                               4981
# 3                                               5000
# 4                                               5000
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011113_aid0001_tif  \
# 0                                               3276
# 1                                               3276
# 2                                               4962
# 3                                               3959
# 4                                               3822
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011129_aid0001_tif  \
# 0                                               2311
# 1                                               2445
# 2                                               3469
# 3                                               4367
# 4                                               3801
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011145_aid0001_tif  \
# 0                                               2988
# 1                                               3072
# 2                                               4083
# 3                                               3958
# 4                                               2854
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011161_aid0001_tif  \
# 0                                               2734
# 1                                               3030
# 2                                               3838
# 3                                               3031
# 4                                               2302
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011177_aid0001_tif  ...  \
# 0                                               4211     ...
# 1                                               4211     ...
# 2                                               5155     ...
# 3                                               3781     ...
# 4                                               3863     ...
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012113_aid0001_tif  \
# 0                                               3416
# 1                                               3400
# 2                                               4230
# 3                                               4808
# 4                                               3525
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012129_aid0001_tif  \
# 0                                               2782
# 1                                               3202
# 2                                               3126
# 3                                               4320
# 4                                               3904
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012145_aid0001_tif  \
# 0                                               4794
# 1                                               5065
# 2                                               4240
# 3                                               5187
# 4                                               5480
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012161_aid0001_tif  \
# 0                                               5903
# 1                                               4745
# 2                                               5217
# 3                                               4801
# 4                                               5388
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012177_aid0001_tif  \
# 0                                               4964
# 1                                               4172
# 2                                               3612
# 3                                               4535
# 4                                               4324
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012193_aid0001_tif  \
# 0                                             5358.0
# 1                                             4764.0
# 2                                             5986.0
# 3                                             5090.0
# 4                                             4456.0
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012209_aid0001_tif  \
# 0                                             5287.0
# 1                                             4815.0
# 2                                             5905.0
# 3                                             4958.0
# 4                                             4866.0
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012225_aid0001_tif  \
# 0                                               3766
# 1                                               3797
# 2                                               4957
# 3                                               4200
# 4                                               3261
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012241_aid0001_tif  rf_irr
# 0                                             3680.0          0
# 1                                             3916.0          0
# 2                                             3974.0          0
# 3                                             3011.0          0
# 4                                             3443.0          0
#
# [5 rows x 25 columns]

# %%
madison_df = pd.concat([madison_rf_df, madison_irr_df])
madison_df["county"] = "Madison"
# Out:
# C:\Users\paul.abers\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
madison_rf_df.info()
madison_irr_df.info()
madison_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5053 entries, 0 to 5052
# Data columns (total 25 columns):
# Longitude                                               5053 non-null float64
# Latitude                                                5053 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2011081_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012081_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011097_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011113_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011129_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011145_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011161_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011177_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011193_aid0001_tif    5051 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2011209_aid0001_tif    5051 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2011225_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011241_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012097_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012113_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012129_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012145_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012161_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012177_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012193_aid0001_tif    5040 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2012209_aid0001_tif    5047 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2012225_aid0001_tif    5053 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012241_aid0001_tif    5043 non-null float64
# rf_irr                                                  5053 non-null int64
# dtypes: float64(7), int64(18)
# memory usage: 987.0 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1288 entries, 0 to 1287
# Data columns (total 25 columns):
# Longitude                                               1288 non-null float64
# Latitude                                                1288 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2012081_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011081_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011097_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011113_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011129_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011145_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011161_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011177_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011193_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011209_aid0001_tif    1282 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2011225_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011241_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012097_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012113_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012129_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012145_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012161_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012177_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012193_aid0001_tif    1283 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2012209_aid0001_tif    1282 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2012225_aid0001_tif    1288 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012241_aid0001_tif    1288 non-null int64
# rf_irr                                                  1288 non-null int64
# dtypes: float64(5), int64(20)
# memory usage: 251.6 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6341 entries, 0 to 1287
# Data columns (total 26 columns):
# Latitude                                                6341 non-null float64
# Longitude                                               6341 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2011081_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011097_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011113_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011129_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011145_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011161_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011177_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011193_aid0001_tif    6339 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2011209_aid0001_tif    6333 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2011225_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2011241_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012081_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012097_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012113_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012129_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012145_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012161_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012177_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012193_aid0001_tif    6323 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2012209_aid0001_tif    6329 non-null float64
# MOD13Q1_006__250m_16_days_EVI_doy2012225_aid0001_tif    6341 non-null int64
# MOD13Q1_006__250m_16_days_EVI_doy2012241_aid0001_tif    6331 non-null float64
# rf_irr                                                  6341 non-null int64
# county                                                  6341 non-null object
# dtypes: float64(7), int64(18), object(1)
# memory usage: 1.3+ MB

# %%
madison_df.head()
# Out:
#     Latitude  Longitude  MOD13Q1_006__250m_16_days_EVI_doy2011081_aid0001_tif  \
# 0  34.990601 -86.779999                                               3413
# 1  34.990601 -86.777496                                               3281
# 2  34.990601 -86.764801                                               4045
# 3  34.990601 -86.757202                                               4167
# 4  34.990601 -86.754600                                               4256
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011097_aid0001_tif  \
# 0                                               4421
# 1                                               4421
# 2                                               4981
# 3                                               5000
# 4                                               5000
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011113_aid0001_tif  \
# 0                                               3276
# 1                                               3276
# 2                                               4962
# 3                                               3959
# 4                                               3822
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011129_aid0001_tif  \
# 0                                               2311
# 1                                               2445
# 2                                               3469
# 3                                               4367
# 4                                               3801
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011145_aid0001_tif  \
# 0                                               2988
# 1                                               3072
# 2                                               4083
# 3                                               3958
# 4                                               2854
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011161_aid0001_tif  \
# 0                                               2734
# 1                                               3030
# 2                                               3838
# 3                                               3031
# 4                                               2302
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011177_aid0001_tif  \
# 0                                               4211
# 1                                               4211
# 2                                               5155
# 3                                               3781
# 4                                               3863
#
#    MOD13Q1_006__250m_16_days_EVI_doy2011193_aid0001_tif  ...  \
# 0                                             5231.0     ...
# 1                                             5960.0     ...
# 2                                             5949.0     ...
# 3                                             5712.0     ...
# 4                                             5656.0     ...
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012129_aid0001_tif  \
# 0                                               2782
# 1                                               3202
# 2                                               3126
# 3                                               4320
# 4                                               3904
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012145_aid0001_tif  \
# 0                                               4794
# 1                                               5065
# 2                                               4240
# 3                                               5187
# 4                                               5480
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012161_aid0001_tif  \
# 0                                               5903
# 1                                               4745
# 2                                               5217
# 3                                               4801
# 4                                               5388
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012177_aid0001_tif  \
# 0                                               4964
# 1                                               4172
# 2                                               3612
# 3                                               4535
# 4                                               4324
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012193_aid0001_tif  \
# 0                                             5358.0
# 1                                             4764.0
# 2                                             5986.0
# 3                                             5090.0
# 4                                             4456.0
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012209_aid0001_tif  \
# 0                                             5287.0
# 1                                             4815.0
# 2                                             5905.0
# 3                                             4958.0
# 4                                             4866.0
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012225_aid0001_tif  \
# 0                                               3766
# 1                                               3797
# 2                                               4957
# 3                                               4200
# 4                                               3261
#
#    MOD13Q1_006__250m_16_days_EVI_doy2012241_aid0001_tif  rf_irr   county
# 0                                             3680.0          0  Madison
# 1                                             3916.0          0  Madison
# 2                                             3974.0          0  Madison
# 3                                             3011.0          0  Madison
# 4                                             3443.0          0  Madison
#
# [5 rows x 26 columns]

# %%
houston_df.head()
# Out:
#         X            Y  Unnamed: 2  Unnamed: 3  RF_Irr  \
# 0  651082  3.46556e+06   31.314623  -85.412285     0.0
# 1  653630  3.46556e+06   31.314289  -85.385513     0.0
# 2  653862  3.46556e+06   31.314259  -85.383079     0.0
# 3  651082  3.46533e+06   31.312532  -85.412315     0.0
# 4  652009  3.46533e+06   31.312412  -85.402580     0.0
#
#   EVI_2011_Apr_7_Houston_tif_rf_1 EVI_2011_Apr_23_Houston_tif_rf  \
# 0                            2800                           3114
# 1                            1530                           1453
# 2                            2076                           1500
# 3                            2029                           1400
# 4                            1854                           2119
#
#   EVI_2011_May_9_Houston_tif_rf EVI_2011_May_25_Houston_tif_rf  \
# 0                          1873                           2989
# 1                          1416                           1364
# 2                          1602                           2063
# 3                          1877                           1343
# 4                          1611                           1549
#
#   EVI_2011_Jun_10_Houston_tif_rf  ... EVI_2012_Apr_6_Houston_tif_rf  \
# 0                           3299  ...                          4270
# 1                           1703  ...                          1699
# 2                           1703  ...                          1435
# 3                           1788  ...                          3220
# 4                           2393  ...                          1547
#
#   EVI_2012_Apr_22_Houston_tif_rf EVI_2012_May_8_Houston_tif_rf  \
# 0                           3417                          2958
# 1                           1418                          1523
# 2                           1754                          1960
# 3                           1678                          2599
# 4                           1861                          1993
#
#   EVI_2012_May_24_Houston_tif_rf EVI_2012_Jun_9_Houston_tif_rf  \
# 0                           2656                          4659
# 1                           1683                          2726
# 2                           1926                          2726
# 3                           2452                          2149
# 4                           2278                          4305
#
#   EVI_2012_Jun_25_Houston_tif_rf EVI_2012_Jul_11_Houston_tif_rf  \
# 0                           3069                           5409
# 1                           2976                           4179
# 2                           2976                           4364
# 3                           2710                           3564
# 4                           4462                           4609
#
#   EVI_2012_Jul_27_Houston_tif_rf EVI_2012_Aug_12_Houston_tif_rf  \
# 0                           5876                           5800
# 1                           4016                           5509
# 2                           4848                           4623
# 3                           5173                           6491
# 4                           5122                           5654
#
#   EVI_2012_Aug_28_Houston_tif_rf
# 0                           5738
# 1                           4558
# 2                           5547
# 3                           6901
# 4                           5367
#
# [5 rows x 25 columns]

# %%
houston_df = houston_df.rename(columns = {"RF_Irr":"rf_irr", "Unnamed: 2":"Latitude", "Unnamed: 3": "Longitude"})
houston_df["county"] = "Houston"

# %%
houston_df.head()
# Out:
#         X            Y   Latitude  Longitude  rf_irr  \
# 0  651082  3.46556e+06  31.314623 -85.412285     0.0
# 1  653630  3.46556e+06  31.314289 -85.385513     0.0
# 2  653862  3.46556e+06  31.314259 -85.383079     0.0
# 3  651082  3.46533e+06  31.312532 -85.412315     0.0
# 4  652009  3.46533e+06  31.312412 -85.402580     0.0
#
#   EVI_2011_Apr_7_Houston_tif_rf_1 EVI_2011_Apr_23_Houston_tif_rf  \
# 0                            2800                           3114
# 1                            1530                           1453
# 2                            2076                           1500
# 3                            2029                           1400
# 4                            1854                           2119
#
#   EVI_2011_May_9_Houston_tif_rf EVI_2011_May_25_Houston_tif_rf  \
# 0                          1873                           2989
# 1                          1416                           1364
# 2                          1602                           2063
# 3                          1877                           1343
# 4                          1611                           1549
#
#   EVI_2011_Jun_10_Houston_tif_rf  ... EVI_2012_Apr_22_Houston_tif_rf  \
# 0                           3299  ...                           3417
# 1                           1703  ...                           1418
# 2                           1703  ...                           1754
# 3                           1788  ...                           1678
# 4                           2393  ...                           1861
#
#   EVI_2012_May_8_Houston_tif_rf EVI_2012_May_24_Houston_tif_rf  \
# 0                          2958                           2656
# 1                          1523                           1683
# 2                          1960                           1926
# 3                          2599                           2452
# 4                          1993                           2278
#
#   EVI_2012_Jun_9_Houston_tif_rf EVI_2012_Jun_25_Houston_tif_rf  \
# 0                          4659                           3069
# 1                          2726                           2976
# 2                          2726                           2976
# 3                          2149                           2710
# 4                          4305                           4462
#
#   EVI_2012_Jul_11_Houston_tif_rf EVI_2012_Jul_27_Houston_tif_rf  \
# 0                           5409                           5876
# 1                           4179                           4016
# 2                           4364                           4848
# 3                           3564                           5173
# 4                           4609                           5122
#
#   EVI_2012_Aug_12_Houston_tif_rf EVI_2012_Aug_28_Houston_tif_rf   county
# 0                           5800                           5738  Houston
# 1                           5509                           4558  Houston
# 2                           4623                           5547  Houston
# 3                           6491                           6901  Houston
# 4                           5654                           5367  Houston
#
# [5 rows x 26 columns]

# %%
limestone_df.head()
# Out:
#         X            Y   Latitude  Longitude  Irr_Rf EVI_2011_APR_7_1  \
# 0  481294  3.86912e+06  34.964485 -87.204903     0.0             3703
# 1  497047  3.86912e+06  34.964657 -87.032349     0.0             3256
# 2  497510  3.86912e+06  34.964657 -87.027275     0.0             2983
# 3  480831  3.86889e+06  34.962391 -87.209976     0.0             3253
# 4  497278  3.86889e+06  34.962566 -87.029808     0.0             3483
#
#   EVI_2011_APR_23_ EVI_2011_MAY_9_L EVI_2011_MAY_25_ EVI_2011_JUN_10_  ...  \
# 0             4247             4079             4472             4666  ...
# 1             2695             2804             5184             3607  ...
# 2             3032             5763             2620             4831  ...
# 3             4592             4797             5969             3677  ...
# 4             3010             4030             2521             2799  ...
#
#   EVI_2012_APR_6_L EVI_2012_APR_22_ EVI_2012_MAY_8_L EVI_2012_MAY_24_  \
# 0             5079             4006             2625             3389
# 1             2830             3187             3997             4780
# 2             2643             3491             3357             4701
# 3             3875             4541             3599             4573
# 4             3308             3166             3811             5268
#
#   EVI_2012_JUN_9_L EVI_2012_JUN_25_ EVI_2012_JUL_11_ EVI_2012_JUL_27_  \
# 0             3895             3660             6504             7270
# 1             4882             3973             4344             4928
# 2             4137             3710             4007             4268
# 3             4612             4019             5942             5880
# 4             4506             3898             6482             4144
#
#   EVI_2012_AUG_12_ EVI_2012_AUG_28_
# 0             6466             6445
# 1             3651             6758
# 2             4408             2721
# 3             6815             5641
# 4             3887             2598
#
# [5 rows x 25 columns]

# %%
limestone_df = limestone_df.rename(columns={"Irr_Rf":"rf_irr"})
limestone_df["county"] = "Limestone"
limestone_df.head()
# Out:
#         X            Y   Latitude  Longitude  rf_irr EVI_2011_APR_7_1  \
# 0  481294  3.86912e+06  34.964485 -87.204903     0.0             3703
# 1  497047  3.86912e+06  34.964657 -87.032349     0.0             3256
# 2  497510  3.86912e+06  34.964657 -87.027275     0.0             2983
# 3  480831  3.86889e+06  34.962391 -87.209976     0.0             3253
# 4  497278  3.86889e+06  34.962566 -87.029808     0.0             3483
#
#   EVI_2011_APR_23_ EVI_2011_MAY_9_L EVI_2011_MAY_25_ EVI_2011_JUN_10_  ...  \
# 0             4247             4079             4472             4666  ...
# 1             2695             2804             5184             3607  ...
# 2             3032             5763             2620             4831  ...
# 3             4592             4797             5969             3677  ...
# 4             3010             4030             2521             2799  ...
#
#   EVI_2012_APR_22_ EVI_2012_MAY_8_L EVI_2012_MAY_24_ EVI_2012_JUN_9_L  \
# 0             4006             2625             3389             3895
# 1             3187             3997             4780             4882
# 2             3491             3357             4701             4137
# 3             4541             3599             4573             4612
# 4             3166             3811             5268             4506
#
#   EVI_2012_JUN_25_ EVI_2012_JUL_11_ EVI_2012_JUL_27_ EVI_2012_AUG_12_  \
# 0             3660             6504             7270             6466
# 1             3973             4344             4928             3651
# 2             3710             4007             4268             4408
# 3             4019             5942             5880             6815
# 4             3898             6482             4144             3887
#
#   EVI_2012_AUG_28_     county
# 0             6445  Limestone
# 1             6758  Limestone
# 2             2721  Limestone
# 3             5641  Limestone
# 4             2598  Limestone
#
# [5 rows x 26 columns]

# %%
@tl.curry
def tokenize(delimiter, string):
    return string.split(delimiter)
tokenizer = tokenize("_")
limestone_tokenized = list(tl.map(tokenizer, limestone_df.columns))
houston_tokenized = list(tl.map(tokenizer, houston_df.columns))
madison_tokenized = list(tl.map(tokenizer, madison_df.columns))
print("limestone")
for tk in limestone_tokenized:
    print(tk)
print("houston")
for tk in houston_tokenized:
    print(tk)
print("madison")
for tk in madison_tokenized:
    print(tk)
# Out:
# limestone
# ['X']
# ['Y']
# ['Latitude']
# ['Longitude']
# ['rf', 'irr']
# ['EVI', '2011', 'APR', '7', '1']
# ['EVI', '2011', 'APR', '23', '']
# ['EVI', '2011', 'MAY', '9', 'L']
# ['EVI', '2011', 'MAY', '25', '']
# ['EVI', '2011', 'JUN', '10', '']
# ['EVI', '2011', 'JUN', '26', '']
# ['EVI', '2011', 'JUL', '12', '']
# ['EVI', '2011', 'JUL', '28', '']
# ['EVI', '2011', 'AUG', '13', '']
# ['EVI', '2011', 'AUG', '29', '']
# ['EVI', '2012', 'APR', '6', 'L']
# ['EVI', '2012', 'APR', '22', '']
# ['EVI', '2012', 'MAY', '8', 'L']
# ['EVI', '2012', 'MAY', '24', '']
# ['EVI', '2012', 'JUN', '9', 'L']
# ['EVI', '2012', 'JUN', '25', '']
# ['EVI', '2012', 'JUL', '11', '']
# ['EVI', '2012', 'JUL', '27', '']
# ['EVI', '2012', 'AUG', '12', '']
# ['EVI', '2012', 'AUG', '28', '']
# ['county']
# houston
# ['X']
# ['Y']
# ['Latitude']
# ['Longitude']
# ['rf', 'irr']
# ['EVI', '2011', 'Apr', '7', 'Houston', 'tif', 'rf', '1']
# ['EVI', '2011', 'Apr', '23', 'Houston', 'tif', 'rf']
# ['EVI', '2011', 'May', '9', 'Houston', 'tif', 'rf']
# ['EVI', '2011', 'May', '25', 'Houston', 'tif', 'rf']
# ['EVI', '2011', 'Jun', '10', 'Houston', 'tif', 'rf']
# ['EVI', '2011', 'Jun', '26', 'Houston', 'tif', 'rf']
# ['EVI', '2011', 'Jul', '12', 'Houston', 'tif', 'rf']
# ['EVI', '2011', 'Jul', '28', 'Houston', 'tif', 'rf']
# ['EVI', '2011', 'Aug', '13', 'Houston', 'tif', 'rf']
# ['EVI', '2011', 'Aug', '29', 'Houston', 'tif', 'rf']
# ['EVI', '2012', 'Apr', '6', 'Houston', 'tif', 'rf']
# ['EVI', '2012', 'Apr', '22', 'Houston', 'tif', 'rf']
# ['EVI', '2012', 'May', '8', 'Houston', 'tif', 'rf']
# ['EVI', '2012', 'May', '24', 'Houston', 'tif', 'rf']
# ['EVI', '2012', 'Jun', '9', 'Houston', 'tif', 'rf']
# ['EVI', '2012', 'Jun', '25', 'Houston', 'tif', 'rf']
# ['EVI', '2012', 'Jul', '11', 'Houston', 'tif', 'rf']
# ['EVI', '2012', 'Jul', '27', 'Houston', 'tif', 'rf']
# ['EVI', '2012', 'Aug', '12', 'Houston', 'tif', 'rf']
# ['EVI', '2012', 'Aug', '28', 'Houston', 'tif', 'rf']
# ['county']
# madison
# ['Latitude']
# ['Longitude']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2011081', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2011097', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2011113', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2011129', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2011145', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2011161', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2011177', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2011193', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2011209', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2011225', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2011241', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2012081', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2012097', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2012113', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2012129', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2012145', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2012161', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2012177', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2012193', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2012209', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2012225', 'aid0001', 'tif']
# ['MOD13Q1', '006', '', '250m', '16', 'days', 'EVI', 'doy2012241', 'aid0001', 'tif']
# ['rf', 'irr']
# ['county']

# %% [markdown]
# From the tokenizers we can see that houston and limestone report date of data in columns 2, 3, 4 of tokenized output (after skipping initial rows). All dates have to hape EVI in their tokenized output. Madison uses a day of year number. Now to move all the data into a consistent format.

# %%
def get_date_time(tokenized_list, county):
    
    def convert_month(month):

        return {
            'jan' : "01",
            'feb' : "02",
            'mar' : "03",
            'apr' : "04",
            'may' : "05",
            'jun' : "06",
            'jul' : "07",
            'aug' : "08",
            'sep' : "09", 
            'oct' : "10",
            'nov' : "11",
            'dec' : "12"
        }[month.lower()]

    if "EVI" not in tokenized_list:
        raise ValueError("EVI not found in tokenized list. Incorrect column name being used.")

    if county != "Madison":
        return tokenized_list[1] + "-" + convert_month(tokenized_list[2]) + "-" + tokenized_list[3].zfill(2)
    else:
        year = tokenized_list[7][3:7]
        day = tokenized_list[7][7:]
        first_day = datetime.date(int(year), 1, 1)
        date = first_day + datetime.timedelta(int(day))
        return str(date.year) + "-" + str(date.month).zfill(2) + "-" + str(date.day).zfill(2)

# %%
def convert_cols(columns, county):
    cols = []
    for col in columns:
        tokenized = tokenize("_", col)
        if "EVI" in tokenized:
            cols.append(get_date_time(tokenized, county))
        else:
            cols.append(col)
    return cols

# %%
madison_df.columns = convert_cols(madison_df.columns, "Madison")
houston_df.columns = convert_cols(houston_df.columns, "Houston")
limestone_df.columns = convert_cols(limestone_df.columns, "Limestone")

# %%
limestone_df = limestone_df.drop(columns=["X", "Y"])
houston_df = houston_df.drop(columns=["X", "Y"])

# %%
print(limestone_df.columns)
print(houston_df.columns)
print(madison_df.columns)
# Out:
# Index(['Latitude', 'Longitude', 'rf_irr', '2011-04-07', '2011-04-23',
#        '2011-05-09', '2011-05-25', '2011-06-10', '2011-06-26', '2011-07-12',
#        '2011-07-28', '2011-08-13', '2011-08-29', '2012-04-06', '2012-04-22',
#        '2012-05-08', '2012-05-24', '2012-06-09', '2012-06-25', '2012-07-11',
#        '2012-07-27', '2012-08-12', '2012-08-28', 'county'],
#       dtype='object')
# Index(['Latitude', 'Longitude', 'rf_irr', '2011-04-07', '2011-04-23',
#        '2011-05-09', '2011-05-25', '2011-06-10', '2011-06-26', '2011-07-12',
#        '2011-07-28', '2011-08-13', '2011-08-29', '2012-04-06', '2012-04-22',
#        '2012-05-08', '2012-05-24', '2012-06-09', '2012-06-25', '2012-07-11',
#        '2012-07-27', '2012-08-12', '2012-08-28', 'county'],
#       dtype='object')
# Index(['Latitude', 'Longitude', '2011-03-23', '2011-04-08', '2011-04-24',
#        '2011-05-10', '2011-05-26', '2011-06-11', '2011-06-27', '2011-07-13',
#        '2011-07-29', '2011-08-14', '2011-08-30', '2012-03-22', '2012-04-07',
#        '2012-04-23', '2012-05-09', '2012-05-25', '2012-06-10', '2012-06-26',
#        '2012-07-12', '2012-07-28', '2012-08-13', '2012-08-29', 'rf_irr',
#        'county'],
#       dtype='object')

# %% [markdown]
# Looking at the columns of the three dataframe we can see that madison has two extra datapoint (2011-03-23 and 2011-03-22). Also the madison dates are each one day ahead of the houston and limestone days. One day makes little difference in the span of vegetation, so I will subtract one from each madison day in order to make all the column names lineup. I will also choose to drop the two extraneous days in the madison data to make all the data match up (considering there are still plenty of days for all three datasets, I do not believe this drop will have a large affect).

# %%
new_cols = []
for col in madison_df.columns:
    if col[0] == "2":
        tk = tokenize("-", col)
        tk[2] = str(int(tk[2])-1).zfill(2)
        new_cols.append("-".join(tk))
    else:
        new_cols.append(col)

# %%
madison_df.columns = new_cols
madison_df = madison_df.drop(columns=["2011-03-22", "2012-03-21"])

# %%
all_df = pd.concat([madison_df, houston_df, limestone_df])
# Out:
# C:\Users\paul.abers\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14677 entries, 0 to 6730
# Data columns (total 24 columns):
# 2011-04-07    14677 non-null object
# 2011-04-23    14677 non-null object
# 2011-05-09    14677 non-null object
# 2011-05-25    14677 non-null object
# 2011-06-10    14677 non-null object
# 2011-06-26    14677 non-null object
# 2011-07-12    14674 non-null object
# 2011-07-28    14669 non-null object
# 2011-08-13    14677 non-null object
# 2011-08-29    14677 non-null object
# 2012-04-06    14677 non-null object
# 2012-04-22    14677 non-null object
# 2012-05-08    14677 non-null object
# 2012-05-24    14677 non-null object
# 2012-06-09    14677 non-null object
# 2012-06-25    14677 non-null object
# 2012-07-11    14657 non-null object
# 2012-07-27    14656 non-null object
# 2012-08-12    14677 non-null object
# 2012-08-28    14667 non-null object
# Latitude      14675 non-null float64
# Longitude     14675 non-null float64
# county        14677 non-null object
# rf_irr        14675 non-null float64
# dtypes: float64(3), object(21)
# memory usage: 2.8+ MB

# %% [markdown]
# As can be seen by the info, not all rows have data. I will drop all rows that contain a single null since it appears there are not many null values.

# %%
all_df_no_na = all_df.dropna()
all_df_no_na = all_df_no_na[all_df_no_na.columns[list(range(-4, len(all_df_no_na.columns)-4, 1))]]
all_df_no_na.reset_index(inplace=True)
all_df_no_na.drop(columns=["index"], inplace=True)

# %%
all_df_no_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14613 entries, 0 to 14612
# Data columns (total 24 columns):
# Latitude      14613 non-null float64
# Longitude     14613 non-null float64
# county        14613 non-null object
# rf_irr        14613 non-null float64
# 2011-04-07    14613 non-null object
# 2011-04-23    14613 non-null object
# 2011-05-09    14613 non-null object
# 2011-05-25    14613 non-null object
# 2011-06-10    14613 non-null object
# 2011-06-26    14613 non-null object
# 2011-07-12    14613 non-null object
# 2011-07-28    14613 non-null object
# 2011-08-13    14613 non-null object
# 2011-08-29    14613 non-null object
# 2012-04-06    14613 non-null object
# 2012-04-22    14613 non-null object
# 2012-05-08    14613 non-null object
# 2012-05-24    14613 non-null object
# 2012-06-09    14613 non-null object
# 2012-06-25    14613 non-null object
# 2012-07-11    14613 non-null object
# 2012-07-27    14613 non-null object
# 2012-08-12    14613 non-null object
# 2012-08-28    14613 non-null object
# dtypes: float64(3), object(21)
# memory usage: 2.7+ MB

# %% [markdown]
# It appears we have not lost many values, which is good. We can now write the data out so that we can use it later in our learning stage.

# %%
all_df_no_na.to_csv(os.path.join(os.getcwd(), "data", "cleaned_data", "all_data.csv"))

# %% [markdown]
# And now we have a clean csv with all the data combined to work with.
