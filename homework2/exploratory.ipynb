# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv(os.path.join(os.getcwd(), "data", "cleaned_data", "all_data.csv"), index_col=0)
df.head()
# Out:
#     Latitude  Longitude   county  rf_irr  2011-04-07  2011-04-23  2011-05-09  \
# 0  34.990601 -86.779999  Madison     0.0        4421        3276        2311
# 1  34.990601 -86.777496  Madison     0.0        4421        3276        2445
# 2  34.990601 -86.764801  Madison     0.0        4981        4962        3469
# 3  34.990601 -86.757202  Madison     0.0        5000        3959        4367
# 4  34.990601 -86.754600  Madison     0.0        5000        3822        3801
#
#    2011-05-25  2011-06-10  2011-06-26  ...  2012-04-06  2012-04-22  \
# 0        2988        2734        4211  ...        3747        3416
# 1        3072        3030        4211  ...        3659        3400
# 2        4083        3838        5155  ...        5169        4230
# 3        3958        3031        3781  ...        3732        4808
# 4        2854        2302        3863  ...        3123        3525
#
#    2012-05-08  2012-05-24  2012-06-09  2012-06-25  2012-07-11  2012-07-27  \
# ...

# %%
df.describe()
# Out:
#            Latitude     Longitude        rf_irr    2011-04-07    2011-04-23  \
# count  14613.000000  14613.000000  14613.000000  14613.000000  14613.000000
# mean      34.382267    -86.595015      0.236639   3919.609731   3648.742832
# std        1.133842      0.500871      0.425033   1646.620460   1653.185464
# min       30.999237    -87.262680      0.000000    155.000000   -496.000000
# 25%       34.631302    -86.903084      0.000000   2518.000000   2216.000000
# 50%       34.747650    -86.745003      0.000000   3785.000000   3359.000000
# 75%       34.876400    -86.470398      0.000000   5150.000000   5008.000000
# max       34.991402    -85.023468      1.000000   8827.000000   8411.000000
#
#          2011-05-09    2011-05-25    2011-06-10    2011-06-26    2011-07-12  \
# count  14613.000000  14613.000000  14613.000000  14613.000000  14613.000000
# mean    3366.328885   3300.604120   3262.998768   4273.409225   5670.318141
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14613 entries, 0 to 6730
# Data columns (total 24 columns):
# Latitude      14613 non-null float64
# Longitude     14613 non-null float64
# county        14613 non-null object
# rf_irr        14613 non-null float64
# 2011-04-07    14613 non-null int64
# 2011-04-23    14613 non-null int64
# 2011-05-09    14613 non-null int64
# 2011-05-25    14613 non-null int64
# 2011-06-10    14613 non-null int64
# 2011-06-26    14613 non-null int64
# 2011-07-12    14613 non-null float64
# 2011-07-28    14613 non-null float64
# 2011-08-13    14613 non-null int64
# 2011-08-29    14613 non-null int64
# 2012-04-06    14613 non-null int64
# 2012-04-22    14613 non-null int64
# 2012-05-08    14613 non-null int64
# 2012-05-24    14613 non-null int64
# 2012-06-09    14613 non-null int64
# 2012-06-25    14613 non-null int64
# 2012-07-11    14613 non-null float64
# 2012-07-27    14613 non-null float64
# 2012-08-12    14613 non-null int64
# ...

# %% [markdown]
# We need to split the data into train, validate, test. But this split needs to be representative of the whole. So we will sample each county separately and sample each flag of rainfed vs irrigated separately

# %%
df_madison = df.loc[df["county"] == "Madison"]

# %%
df_madison.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6291 entries, 0 to 1287
# Data columns (total 24 columns):
# Latitude      6291 non-null float64
# Longitude     6291 non-null float64
# county        6291 non-null object
# rf_irr        6291 non-null float64
# 2011-04-07    6291 non-null int64
# 2011-04-23    6291 non-null int64
# 2011-05-09    6291 non-null int64
# 2011-05-25    6291 non-null int64
# 2011-06-10    6291 non-null int64
# 2011-06-26    6291 non-null int64
# 2011-07-12    6291 non-null float64
# 2011-07-28    6291 non-null float64
# 2011-08-13    6291 non-null int64
# 2011-08-29    6291 non-null int64
# 2012-04-06    6291 non-null int64
# 2012-04-22    6291 non-null int64
# 2012-05-08    6291 non-null int64
# 2012-05-24    6291 non-null int64
# 2012-06-09    6291 non-null int64
# 2012-06-25    6291 non-null int64
# 2012-07-11    6291 non-null float64
# 2012-07-27    6291 non-null float64
# 2012-08-12    6291 non-null int64
# 2012-08-28    6291 non-null float64
# ...

# %%
df_houston = df.loc[df["county"] == "Houston"]

# %%
df_limestone = df.loc[df["county"] == "Limestone"]

# %%
indices = {}
for county_df in [df_houston, df_limestone, df_madison]:
    rf_indices = county_df.loc[county_df["rf_irr"] == 0].index.values
    irr_indices = county_df.loc[county_df["rf_irr"] == 1].index.values
    county = county_df.iloc[0, :].loc["county"]
    indices[county + "_rf"] = rf_indices
    indices[county + "_irr"] = irr_indices

# %%
for key, val in indices.items():
    print(key)
    print(len(val))
# Out:
# Houston_rf
# 1372
# Houston_irr
# 220
# Limestone_rf
# 4763
# Limestone_irr
# 1967
# Madison_rf
# 5020
# Madison_irr
# 1271

# %%
def split_indices(alist, train=0.25, validate=0.25, test=0.5, **kwargs):
    def almost_equals(left, right, tol=0.0001):
        if abs(left - right) < tol:
            return True
    
    if not almost_equals(train+validate+test, 1):
        raise ValueError("Train + validate + test should equal 1")
    
    copylist = copy.copy(alist)
    
    seed = kwargs.get("seed", 42)
    np.random.seed(seed)
    np.random.shuffle(alist)
    
    num = len(copylist)
    train_stop = int(num*train)
    validate_stop = int(num*validate) + train_stop
    
    
    return copylist[:train_stop], copylist[train_stop:validate_stop], copylist[validate_stop:]

# %%
train = []
validate = []
test = []
for key, val in indices.items():
    tr, va, te = split_indices(val)
    train.append(tr)
    validate.append(va)
    test.append(te)
train = np.concatenate(train)
validate = np.concatenate(validate)
test = np.concatenate(test)

# %%
train_df = df.iloc[train, :]
validate_df = df.iloc[validate, :]
test_df = df.iloc[test, :]

# %%
train_df.info()
validate_df.info()
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3651 entries, 0 to 321
# Data columns (total 24 columns):
# Latitude      3651 non-null float64
# Longitude     3651 non-null float64
# county        3651 non-null object
# rf_irr        3651 non-null float64
# 2011-04-07    3651 non-null int64
# 2011-04-23    3651 non-null int64
# 2011-05-09    3651 non-null int64
# 2011-05-25    3651 non-null int64
# 2011-06-10    3651 non-null int64
# 2011-06-26    3651 non-null int64
# 2011-07-12    3651 non-null float64
# 2011-07-28    3651 non-null float64
# 2011-08-13    3651 non-null int64
# 2011-08-29    3651 non-null int64
# 2012-04-06    3651 non-null int64
# 2012-04-22    3651 non-null int64
# 2012-05-08    3651 non-null int64
# 2012-05-24    3651 non-null int64
# 2012-06-09    3651 non-null int64
# 2012-06-25    3651 non-null int64
# 2012-07-11    3651 non-null float64
# 2012-07-27    3651 non-null float64
# 2012-08-12    3651 non-null int64
# 2012-08-28    3651 non-null float64
# ...

# %%
train_df.describe()
# Out:
#           Latitude    Longitude       rf_irr   2011-04-07   2011-04-23  \
# count  3651.000000  3651.000000  3651.000000  3651.000000  3651.000000
# mean     34.924276   -86.594555     0.064366  4937.987949  4277.871816
# std       0.108704     0.106557     0.245437  1298.133723  1648.577890
# min      34.477798   -86.782700     0.000000   935.000000  1139.000000
# 25%      34.921600   -86.693752     0.000000  4154.000000  2886.000000
# 50%      34.954899   -86.594704     0.000000  4896.000000  4268.000000
# 75%      34.976400   -86.516403     0.000000  5806.000000  5628.000000
# max      34.990601   -86.308899     1.000000  8129.000000  8125.000000
#
#         2011-05-09   2011-05-25   2011-06-10   2011-06-26   2011-07-12  ...  \
# count  3651.000000  3651.000000  3651.000000  3651.000000  3651.000000  ...
# mean   3931.778691  3811.269241  3647.892084  4536.705560  6015.312243  ...
# std    1238.183050  1168.477632  1075.763524  1393.533698  1099.615020  ...
# ...

# %%
validate_df.describe()
# Out:
#           Latitude    Longitude       rf_irr   2011-04-07   2011-04-23  \
# count  3651.000000  3651.000000  3651.000000  3651.000000  3651.000000
# mean     34.872538   -86.614578     0.134484  3904.175021  3377.636538
# std       0.051452     0.085618     0.341218  1482.830854  1645.981538
# min      34.747299   -86.782997     0.000000  1257.000000   941.000000
# 25%      34.833599   -86.686500     0.000000  2676.000000  2020.000000
# 50%      34.869301   -86.621300     0.000000  3820.000000  3019.000000
# 75%      34.896400   -86.534699     0.000000  4911.000000  4540.500000
# max      34.970902   -86.465897     1.000000  8827.000000  8285.000000
#
#         2011-05-09   2011-05-25   2011-06-10   2011-06-26   2011-07-12  ...  \
# count  3651.000000  3651.000000  3651.000000  3651.000000  3651.000000  ...
# mean   3211.183511  3243.126815  3171.332786  4392.329499  6235.763079  ...
# std    1275.462550  1117.112297  1012.110697  1317.132243  1204.410215  ...
# ...

# %%
test_df.describe()
# Out:
#           Latitude    Longitude       rf_irr   2011-04-07   2011-04-23  \
# count  7311.000000  7311.000000  7311.000000  7311.000000  7311.000000
# mean     34.541935   -86.447005     0.079059  4024.771030  3704.278484
# std       0.858971     0.281786     0.269849  1513.696471  1587.857317
# min      31.070805   -86.788696     0.000000   383.000000   137.000000
# 25%      34.590099   -86.572098     0.000000  2837.000000  2408.000000
# 50%      34.733501   -86.451698     0.000000  3897.000000  3436.000000
# 75%      34.902100   -86.404800     0.000000  5045.000000  4894.000000
# max      34.991402   -85.349441     1.000000  8129.000000  8411.000000
#
#         2011-05-09   2011-05-25   2011-06-10   2011-06-26   2011-07-12  ...  \
# count  7311.000000  7311.000000  7311.000000  7311.000000  7311.000000  ...
# mean   3398.963616  3276.414718  3185.952674  4197.455341  5790.369443  ...
# std    1256.282974  1183.740584  1025.265529  1337.479374  1319.601423  ...
# ...

# %% [markdown]
# From the counts of the three dataframes and the mean/std of the rf_irr in the dataframes we can tell that all three got the right size and have similar percentages of rainfed and irrigated fields.

# %%
def extract_in_out(df):
    x_in = df.drop(columns=["rf_irr", "county"]).to_numpy()
    y_out = df.loc[:, ["rf_irr"]].to_numpy()
    return x_in, y_out

# %%
X_train, y_train = extract_in_out(train_df)
X_validate, y_validate = extract_in_out(validate_df)
X_test, y_test = extract_in_out(test_df)

# %%
clf_tree = DecisionTreeClassifier(criterion='gini', max_depth=4, random_state=1)

clf_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=1,
#             splitter='best')

# %%
print(f"Train Score:\t\t{clf_tree.score(X_train, y_train)}")
print(f"Validate Score:\t\t{clf_tree.score(X_validate, y_validate)}")
print(f"Test Score:\t\t{clf_tree.score(X_test, y_test)}")
# Out:
# Train Score:		0.9449465899753492
# Validate Score:		0.8805806628321008
# Test Score:		0.9209410477362878

# %% [markdown]
# This setup seems to all work. Now to test it with various different parameters for the tree and see how the score changes.
